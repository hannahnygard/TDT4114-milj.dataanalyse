# %%
import pandas as pd
import json

# %%
def fra_json_til_dataframe(filnavn):
    with open(filnavn, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    # Henter observasjonene
    observationer = data.get("data", [])
    
    # Definerer tomme rader først
    rader = []

    for obs in observationer:
        source_id = obs.get('sourceId', None)
        reference_time = obs.get('referenceTime', None)


    # For hver observasjon kan vi lage en rad med informasjonen vi trenger
        for observation in obs.get('observations', []):
            rader.append({
                'sourceId': source_id,
                'referenceTime': reference_time,
                'elementId': observation.get('elementId', None),
                'value': observation.get('value', None),
                'unit': observation.get('unit', None),
                'timeOffset': observation.get('timeOffset', None),
                'performanceCategory': observation.get('performanceCategory', None)
            })
    
    # Lag en Pandas DataFrame
    df = pd.DataFrame(rader)
    return df

# %%
# Les fra JSON - nedbør
df_nedbor = fra_json_til_dataframe("frost_nedbor.json")


# Skriv ut dataene i tabell
print("Nedbør:")
display(df_nedbor)
# Out:
# Nedbør:
#       sourceId             referenceTime                      elementId  \
# 0    SN18700:0  2023-01-01T00:00:00.000Z  sum(precipitation_amount P1D)
# 1    SN18700:0  2023-01-01T00:00:00.000Z  sum(precipitation_amount P1D)
# 2    SN18700:0  2023-01-02T00:00:00.000Z  sum(precipitation_amount P1D)
# 3    SN18700:0  2023-01-02T00:00:00.000Z  sum(precipitation_amount P1D)
# 4    SN18700:0  2023-01-03T00:00:00.000Z  sum(precipitation_amount P1D)
# ..         ...                       ...                            ...
# 723  SN18700:0  2023-12-28T00:00:00.000Z  sum(precipitation_amount P1D)
# 724  SN18700:0  2023-12-29T00:00:00.000Z  sum(precipitation_amount P1D)
# 725  SN18700:0  2023-12-29T00:00:00.000Z  sum(precipitation_amount P1D)
# 726  SN18700:0  2023-12-30T00:00:00.000Z  sum(precipitation_amount P1D)
# 727  SN18700:0  2023-12-30T00:00:00.000Z  sum(precipitation_amount P1D)
#
#      value unit timeOffset performanceCategory
# 0      0.0   mm      PT18H                   C
# 1      0.0   mm       PT6H                   C
# 2      0.6   mm      PT18H                   C
# 3      0.6   mm       PT6H                   C
# 4      0.0   mm      PT18H                   C
# ..     ...  ...        ...                 ...
# 723    2.2   mm       PT6H                   C
# 724    6.3   mm      PT18H                   C
# 725    5.5   mm       PT6H                   C
# 726    0.4   mm      PT18H                   C
# 727    1.8   mm       PT6H                   C
#
# [728 rows x 7 columns]

# %%
#Les fra JSON - temp
df_temp = fra_json_til_dataframe("frost_temp.json")


#Skriv ut på tabell:
print("Temperatur:")
display(df_temp)
# Out:
# Temperatur:
#      sourceId             referenceTime  \
# 0   SN18700:0  1980-01-01T00:00:00.000Z
# 1   SN18700:0  1981-01-01T00:00:00.000Z
# 2   SN18700:0  1982-01-01T00:00:00.000Z
# 3   SN18700:0  1983-01-01T00:00:00.000Z
# 4   SN18700:0  1984-01-01T00:00:00.000Z
# 5   SN18700:0  1985-01-01T00:00:00.000Z
# 6   SN18700:0  1986-01-01T00:00:00.000Z
# 7   SN18700:0  1987-01-01T00:00:00.000Z
# 8   SN18700:0  1988-01-01T00:00:00.000Z
# 9   SN18700:0  1989-01-01T00:00:00.000Z
# 10  SN18700:0  1990-01-01T00:00:00.000Z
# 11  SN18700:0  1991-01-01T00:00:00.000Z
# 12  SN18700:0  1992-01-01T00:00:00.000Z
# 13  SN18700:0  1993-01-01T00:00:00.000Z
# 14  SN18700:0  1994-01-01T00:00:00.000Z
# 15  SN18700:0  1995-01-01T00:00:00.000Z
# 16  SN18700:0  1996-01-01T00:00:00.000Z
# 17  SN18700:0  1997-01-01T00:00:00.000Z
# 18  SN18700:0  1998-01-01T00:00:00.000Z
# 19  SN18700:0  1999-01-01T00:00:00.000Z
# 20  SN18700:0  2000-01-01T00:00:00.000Z
# 21  SN18700:0  2001-01-01T00:00:00.000Z
# 22  SN18700:0  2002-01-01T00:00:00.000Z
# 23  SN18700:0  2003-01-01T00:00:00.000Z
# 24  SN18700:0  2004-01-01T00:00:00.000Z
# 25  SN18700:0  2005-01-01T00:00:00.000Z
# 26  SN18700:0  2006-01-01T00:00:00.000Z
# 27  SN18700:0  2007-01-01T00:00:00.000Z
# 28  SN18700:0  2008-01-01T00:00:00.000Z
# 29  SN18700:0  2009-01-01T00:00:00.000Z
# 30  SN18700:0  2010-01-01T00:00:00.000Z
# 31  SN18700:0  2011-01-01T00:00:00.000Z
# 32  SN18700:0  2012-01-01T00:00:00.000Z
# 33  SN18700:0  2013-01-01T00:00:00.000Z
# 34  SN18700:0  2014-01-01T00:00:00.000Z
# 35  SN18700:0  2015-01-01T00:00:00.000Z
# 36  SN18700:0  2016-01-01T00:00:00.000Z
# 37  SN18700:0  2017-01-01T00:00:00.000Z
# 38  SN18700:0  2018-01-01T00:00:00.000Z
# 39  SN18700:0  2019-01-01T00:00:00.000Z
# 40  SN18700:0  2020-01-01T00:00:00.000Z
#
#                                   elementId  value  unit timeOffset  \
# 0   best_estimate_mean(air_temperature P1Y)  5.400  degC       PT0H
# 1   best_estimate_mean(air_temperature P1Y)  5.200  degC       PT0H
# 2   best_estimate_mean(air_temperature P1Y)  6.200  degC       PT0H
# 3   best_estimate_mean(air_temperature P1Y)  7.000  degC       PT0H
# 4   best_estimate_mean(air_temperature P1Y)  6.700  degC       PT0H
# 5   best_estimate_mean(air_temperature P1Y)  4.400  degC       PT0H
# 6   best_estimate_mean(air_temperature P1Y)  5.500  degC       PT0H
# 7   best_estimate_mean(air_temperature P1Y)  4.600  degC       PT0H
# 8   best_estimate_mean(air_temperature P1Y)  6.600  degC       PT0H
# 9   best_estimate_mean(air_temperature P1Y)  7.700  degC       PT0H
# 10  best_estimate_mean(air_temperature P1Y)  7.800  degC       PT0H
# 11  best_estimate_mean(air_temperature P1Y)  6.700  degC       PT0H
# 12  best_estimate_mean(air_temperature P1Y)  7.100  degC       PT0H
# 13  best_estimate_mean(air_temperature P1Y)  6.100  degC       PT0H
# 14  best_estimate_mean(air_temperature P1Y)  6.300  degC       PT0H
# 15  best_estimate_mean(air_temperature P1Y)  6.400  degC       PT0H
# 16  best_estimate_mean(air_temperature P1Y)  5.300  degC       PT0H
# 17  best_estimate_mean(air_temperature P1Y)  7.200  degC       PT0H
# 18  best_estimate_mean(air_temperature P1Y)  6.400  degC       PT0H
# 19  best_estimate_mean(air_temperature P1Y)  6.800  degC       PT0H
# 20  best_estimate_mean(air_temperature P1Y)  7.800  degC       PT0H
# 21  best_estimate_mean(air_temperature P1Y)  6.200  degC       PT0H
# 22  best_estimate_mean(air_temperature P1Y)  7.000  degC       PT0H
# 23  best_estimate_mean(air_temperature P1Y)  7.000  degC       PT0H
# 24  best_estimate_mean(air_temperature P1Y)  7.200  degC       PT0H
# 25  best_estimate_mean(air_temperature P1Y)  7.400  degC       PT0H
# 26  best_estimate_mean(air_temperature P1Y)  7.700  degC       PT0H
# 27  best_estimate_mean(air_temperature P1Y)  7.183  degC       PT0H
# 28  best_estimate_mean(air_temperature P1Y)  7.500  degC       PT0H
# 29  best_estimate_mean(air_temperature P1Y)  6.700  degC       PT0H
# 30  best_estimate_mean(air_temperature P1Y)  4.842  degC       PT0H
# 31  best_estimate_mean(air_temperature P1Y)  7.383  degC       PT0H
# 32  best_estimate_mean(air_temperature P1Y)  6.567  degC       PT0H
# 33  best_estimate_mean(air_temperature P1Y)  6.708  degC       PT0H
# 34  best_estimate_mean(air_temperature P1Y)  8.292  degC       PT0H
# 35  best_estimate_mean(air_temperature P1Y)  7.625  degC       PT0H
# 36  best_estimate_mean(air_temperature P1Y)  7.300  degC       PT0H
# 37  best_estimate_mean(air_temperature P1Y)  6.942  degC       PT0H
# 38  best_estimate_mean(air_temperature P1Y)  7.750  degC       PT0H
# 39  best_estimate_mean(air_temperature P1Y)  7.283  degC       PT0H
# 40  best_estimate_mean(air_temperature P1Y)  8.717  degC       PT0H
#
#    performanceCategory
# 0                    C
# 1                    C
# 2                    C
# 3                    C
# 4                    C
# 5                    C
# 6                    C
# 7                    C
# 8                    C
# 9                    C
# 10                   C
# 11                   C
# 12                   C
# 13                   C
# 14                   C
# 15                   C
# 16                   C
# 17                   C
# 18                   C
# 19                   C
# 20                   C
# 21                   C
# 22                   C
# 23                   C
# 24                   C
# 25                   C
# 26                   C
# 27                   C
# 28                   C
# 29                   C
# 30                   C
# 31                   C
# 32                   C
# 33                   C
# 34                   C
# 35                   C
# 36                   C
# 37                   C
# 38                   C
# 39                   C
# 40                   C
